# %% [markdown]
# <a href="https://colab.research.google.com/github/gabeorlanski/question-simplification/blob/master/ZEST_Baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/allenai/zest.git
# %cd zest
# Out:
# Cloning into 'zest'...
# remote: Enumerating objects: 120, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 120 (delta 26), reused 113 (delta 21), pack-reused 0
# Receiving objects: 100% (120/120), 76.18 KiB | 3.05 MiB/s, done.
# Resolving deltas: 100% (26/26), done.
# /content/zest

# %%
# !wget https://ai2-public-datasets.s3.amazonaws.com/zest/zest.zip
# !unzip zest.zip
# Out:
# --2021-09-19 04:02:42--  https://ai2-public-datasets.s3.amazonaws.com/zest/zest.zip
# Resolving ai2-public-datasets.s3.amazonaws.com (ai2-public-datasets.s3.amazonaws.com)... 52.92.162.17
# Connecting to ai2-public-datasets.s3.amazonaws.com (ai2-public-datasets.s3.amazonaws.com)|52.92.162.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5796188 (5.5M) [binary/octet-stream]
# Saving to: ‘zest.zip’
#
# zest.zip            100%[===================>]   5.53M  9.93MB/s    in 0.6s
#
# 2021-09-19 04:02:43 (9.93 MB/s) - ‘zest.zip’ saved [5796188/5796188]
#
# Archive:  zest.zip
#    creating: zest/
#   inflating: zest/test_unanswered.jsonl
#   inflating: zest/README.md
#   inflating: zest/train.jsonl
#   inflating: zest/dev.jsonl

# %%
# !./bin/install
# !pip install tensorflow_datasets==3.2.1
# !pip install allennlp==0.9.0
# Out:
# ...
#      |████████████████████████████████| 1.6 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 816 kB 68.1 MB/s
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
#   Attempting uninstall: pip
#     Found existing installation: pip 21.1.3
#     Uninstalling pip-21.1.3:
#       Successfully uninstalled pip-21.1.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...
#      |████████████████████████████████| 81 kB 4.0 MB/s
# ...
#      |████████████████████████████████| 1.5 MB 11.6 MB/s
# ...
#      |████████████████████████████████| 10.4 MB 43.7 MB/s
# ...
#      |████████████████████████████████| 118 kB 59.5 MB/s
# ...

# %%
# %env ZEST_DATASET_DIR=zest/zest
# %env ZEST_PREPROCESSED_DATASET_DIR=zest/preprocessed
# %env ZEST_TFDS_DATASETS_DIR=zest/tfds

# %%
# !./bin/preprocess.py

# %%
# !./bin/verify
# Out:
# Analyzing /content/zest/bin/fine-tune.py.
# All done! ✨ 🍰 ✨
# 1 file would be left unchanged.
# Analyzing /content/zest/bin/predict.py.
# All done! ✨ 🍰 ✨
# 1 file would be left unchanged.
# Analyzing /content/zest/bin/preprocess.py.
# All done! ✨ 🍰 ✨
# 1 file would be left unchanged.
# Analyzing /content/zest/src/zest.
# All done! ✨ 🍰 ✨
# 8 files would be left unchanged.
# Analyzing /content/zest/tests.
# All done! ✨ 🍰 ✨
# 12 files would be left unchanged.
# Running tests.
# ============================= test session starts ==============================
# platform linux -- Python 3.7.12, pytest-5.3.3, py-1.10.0, pluggy-0.13.1
# rootdir: /content/zest, inifile: setup.cfg
# plugins: typeguard-2.7.1
# collected 0 items / 1 error
#
# ==================================== ERRORS ====================================
# __________________ ERROR collecting tests/zest/test_utils.py ___________________
# ImportError while importing test module '/content/zest/tests/zest/test_utils.py'.
# ...
